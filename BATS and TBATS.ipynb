# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exploration

# %%
#Now we read the CSV file containing our data
data = pd.read_csv(r'C:\Users\gowth\Desktop\Praxis Python\Term - 2\TSF\TSF HW\time-series-analysis-master\time-series-analysis-master\data\daily_traffic.csv')
data = data.dropna()
data.head()
# Out:
#          date_time  traffic_volume
# 0  9/29/2016 17:00          5551.0
# 1  9/29/2016 18:00          4132.0
# 2  9/29/2016 19:00          3435.0
# 3  9/29/2016 20:00          2765.0
# 4  9/29/2016 21:00          2443.0

# %%
#we can now visualize our data
#Hourly traffic volume on the interstate 94, in Minneapolis, Minnesota 
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(data['traffic_volume'])
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

# plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
# plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# #### From the figure above, we can clearly see that we have two seasonal periods. Let’s zoom in and label the days of the week to identify both periods.

# %%
#Hourly traffic volume, westbound, on the interstate 94 in Minneapolis, 
# Minnesota.Here we can see both a daily seasonality (more cars are on the road during the day than during the night), 
# but also a weekly seasonality (more car are on the road Monday to Friday, than during the weekends). 
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(data['traffic_volume']
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# #### 1.Of course, we recognize the plot from the beginning of this article and notice that the traffic volume is indeed lower during the weekend than during the weekdays. Also, we see a daily seasonality, with traffic being heavier during the day than at night.
#
# #### 2.Therefore, we have two periods: the daily period has a length of 24 hours, and the weekly period has a length of 168 hours. Let’s keep that in mind as we move on to modeling.

# %% [markdown]
# ## Modeling

# %%
#We are now ready to start modeling our data. Here, we use the sktime package. I just discovered this framework which brings many statistical and machine learning methods for time series. It also uses a similar syntax convention to scikit-learn, making it easy to use.
#The first step is to define our target and define the forecast horizon. Here, the target is the traffic volume itself. For the forecast horizon, we wish to predict one week of data. Since we have hourly data, we must then predict 168 timesteps (7 * 24) into the future.
y = data['traffic_volume']
fh = np.arange(1, 168)

# %%
pip install sktime
# Out:
# Collecting sktime
#   Downloading sktime-0.15.0-py3-none-any.whl (15.9 MB)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (0.13.2)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (1.0.2)
# Requirement already satisfied: numba>=0.55 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (0.55.1)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (1.21.5)
# Requirement already satisfied: pandas<1.6.0,>=1.1.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (1.4.2)
# Requirement already satisfied: scipy<2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime) (1.7.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\gowth\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime) (1.12.1)
# Requirement already satisfied: setuptools in c:\users\gowth\anaconda3\lib\site-packages (from numba>=0.55->sktime) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\gowth\anaconda3\lib\site-packages (from numba>=0.55->sktime) (0.38.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gowth\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gowth\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.1.0->sktime) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gowth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<1.6.0,>=1.1.0->sktime) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\gowth\anaconda3\lib\site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\gowth\anaconda3\lib\site-packages (from statsmodels>=0.12.1->sktime) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\gowth\anaconda3\lib\site-packages (from statsmodels>=0.12.1->sktime) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gowth\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.12.1->sktime) (3.0.4)
# Installing collected packages: deprecated, sktime
# Successfully installed deprecated-1.2.13 sktime-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Then, we split our data into a training set and a test set. We will keep the last week of data as a test set in order to evaluate our predictions.
# Here, we use the temporal_train_test_split function from sktime
from sktime.forecasting.model_selection import temporal_train_test_split

y_train, y_test = temporal_train_test_split(y, test_size=168)

# %%
#Optionally, we can visualize our test set
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(y_train, ls='-', label='Train')
ax.plot(y_test, ls='--', label='Test')
ax.set_xlabel('time')
ax.set_ylabel('Daily traffic volu,e')
ax.legend(loc='best')

fig.autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Visualizing the training set and test set. The test is simply the last week of data, as shown by the dashed orange line. The rest is used for fitting the models.

# %% [markdown]
# ### Baseline

# %%
# Before we implement our more complex BATS and TBATS models, it’s always a good idea to have a baseline model. That way, we can determine if our more complex forecasting methods are actually performant.
# Here, the simplest baseline I can think of is simply repeating the last week of data from the training set into the future.

# %%
y_pred_baseline = y_train[-168:].values

# %% [markdown]
# ### BATS

# %%
# Now that we have a baseline, let’s move on to implementing the BATS model.
# We first import the BATS model from sktime. Then, we specify the parameters of the model for training. 
# Here, we want to use the Box-Cox transformation as we are dealing with non-linear data. 
# Then, since our dataset does not have an apparent trend, we remove those components from the model. 
# Finally, we specify the seasonal periods, which are 24 (for the daily seasonality) and 168 (for the weekly seasonality).
# Once the model is specified, we simply fit it on the training set and generate the predictions over the forecast horizon.
# All of the steps outlined above translate into the code below.

# %%
pip install sktime[all_extras]
# Out:
# Requirement already satisfied: sktime[all_extras] in c:\users\gowth\anaconda3\lib\site-packages (0.15.0)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (1.2.13)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (0.13.2)
# Requirement already satisfied: scipy<2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (1.7.3)
# Requirement already satisfied: numpy<1.25,>=1.21.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (1.21.5)
# Requirement already satisfied: numba>=0.55 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (0.55.1)
# Requirement already satisfied: scikit-learn<1.3.0,>=0.24.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (1.0.2)
# Requirement already satisfied: pandas<1.6.0,>=1.1.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (1.4.2)
# Collecting hmmlearn>=0.2.7
#   Downloading hmmlearn-0.2.8-cp39-cp39-win_amd64.whl (110 kB)
# Requirement already satisfied: h5py in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (3.6.0)
# Collecting pykalman>=0.9.5
#   Downloading pykalman-0.9.5.tar.gz (228 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Requirement already satisfied: xarray in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (0.20.1)
# Collecting pyod>=0.8.0
#   Downloading pyod-1.0.7.tar.gz (147 kB)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.2-py3-none-any.whl (43 kB)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (2.0.2)
# Requirement already satisfied: dask in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (2022.2.1)
# Collecting tslearn>=0.5.2
#   Downloading tslearn-0.5.2-cp39-cp39-win_amd64.whl (460 kB)
# Collecting tsfresh>=0.17.0
#   Downloading tsfresh-0.20.0-py2.py3-none-any.whl (98 kB)
# Collecting scikit-posthocs>=0.6.5
#   Downloading scikit_posthocs-0.7.0-py3-none-any.whl (38 kB)
# Collecting dtw-python
#   Downloading dtw_python-1.3.0-cp39-cp39-win_amd64.whl (303 kB)
# Collecting statsforecast>=0.5.2
#   Downloading statsforecast-1.4.0-py3-none-any.whl (91 kB)
# Collecting esig==0.9.7
#   Downloading esig-0.9.7-cp39-cp39-win_amd64.whl (4.3 MB)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (0.11.2)
# Collecting filterpy>=1.4.5
#   Downloading filterpy-1.4.5.zip (177 kB)
# Collecting prophet>=1.1
#   Downloading prophet-1.1.1-cp39-cp39-win_amd64.whl (12.1 MB)
# Collecting keras-self-attention
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Collecting tensorflow-probability
#   Downloading tensorflow_probability-0.19.0-py2.py3-none-any.whl (6.7 MB)
# Collecting mne
#   Downloading mne-1.3.0-py3-none-any.whl (7.6 MB)
# Requirement already satisfied: matplotlib>=3.3.2 in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (3.5.1)
# Collecting gluonts>=0.9.0
#   Downloading gluonts-0.11.6-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: cloudpickle in c:\users\gowth\anaconda3\lib\site-packages (from sktime[all_extras]) (2.0.0)
# Collecting stumpy>=1.5.1
#   Downloading stumpy-1.11.1-py3-none-any.whl (136 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\gowth\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime[all_extras]) (1.12.1)
# Requirement already satisfied: tqdm~=4.23 in c:\users\gowth\anaconda3\lib\site-packages (from gluonts>=0.9.0->sktime[all_extras]) (4.64.0)
# Requirement already satisfied: pydantic~=1.7 in c:\users\gowth\anaconda3\lib\site-packages (from gluonts>=0.9.0->sktime[all_extras]) (1.10.2)
# Requirement already satisfied: toolz~=0.10 in c:\users\gowth\anaconda3\lib\site-packages (from gluonts>=0.9.0->sktime[all_extras]) (0.11.2)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\gowth\anaconda3\lib\site-packages (from gluonts>=0.9.0->sktime[all_extras]) (4.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gowth\anaconda3\lib\site-packages (from matplotlib>=3.3.2->sktime[all_extras]) (9.0.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\gowth\anaconda3\lib\site-packages (from numba>=0.55->sktime[all_extras]) (0.38.0)
# Requirement already satisfied: setuptools in c:\users\gowth\anaconda3\lib\site-packages (from numba>=0.55->sktime[all_extras]) (61.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gowth\anaconda3\lib\site-packages (from pandas<1.6.0,>=1.1.0->sktime[all_extras]) (2021.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (0.29.28)
# Requirement already satisfied: urllib3 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (1.26.9)
# Requirement already satisfied: joblib>=0.11 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->sktime[all_extras]) (1.1.0)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.0.8-py3-none-any.whl (81 kB)
# Collecting setuptools-git>=1.2
#   Downloading setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: wheel>=0.37.0 in c:\users\gowth\anaconda3\lib\site-packages (from prophet>=1.1->sktime[all_extras]) (0.37.1)
# Collecting holidays>=0.14.2
#   Downloading holidays-0.18-py3-none-any.whl (195 kB)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
# Collecting korean-lunar-calendar
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting hijri-converter
#   Downloading hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.4-cp39-cp39-win_amd64.whl (1.4 MB)
# Requirement already satisfied: six in c:\users\gowth\anaconda3\lib\site-packages (from pyod>=0.8.0->sktime[all_extras]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from scikit-learn<1.3.0,>=0.24.0->sktime[all_extras]) (2.2.0)
# Collecting numpy<1.25,>=1.21.0
#   Downloading numpy-1.21.6-cp39-cp39-win_amd64.whl (14.0 MB)
# Requirement already satisfied: plotly in c:\users\gowth\anaconda3\lib\site-packages (from statsforecast>=0.5.2->sktime[all_extras]) (5.6.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\gowth\anaconda3\lib\site-packages (from statsmodels>=0.12.1->sktime[all_extras]) (0.5.2)
# Requirement already satisfied: colorama in c:\users\gowth\anaconda3\lib\site-packages (from tqdm~=4.23->gluonts>=0.9.0->sktime[all_extras]) (0.4.4)
# Requirement already satisfied: distributed>=2.11.0 in c:\users\gowth\anaconda3\lib\site-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2022.2.1)
# Requirement already satisfied: requests>=2.9.1 in c:\users\gowth\anaconda3\lib\site-packages (from tsfresh>=0.17.0->sktime[all_extras]) (2.27.1)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\gowth\anaconda3\lib\site-packages (from dask->sktime[all_extras]) (2022.2.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\gowth\anaconda3\lib\site-packages (from dask->sktime[all_extras]) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\gowth\anaconda3\lib\site-packages (from dask->sktime[all_extras]) (6.0)
# Requirement already satisfied: click>=6.6 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (8.0.4)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.0.2)
# Requirement already satisfied: psutil>=5.0 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (5.8.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.7.0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (6.1)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.0.0)
# Requirement already satisfied: jinja2 in c:\users\gowth\anaconda3\lib\site-packages (from distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.11.3)
# Requirement already satisfied: locket in c:\users\gowth\anaconda3\lib\site-packages (from partd>=0.3.10->dask->sktime[all_extras]) (0.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gowth\anaconda3\lib\site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gowth\anaconda3\lib\site-packages (from requests>=2.9.1->tsfresh>=0.17.0->sktime[all_extras]) (2021.10.8)
# Requirement already satisfied: heapdict in c:\users\gowth\anaconda3\lib\site-packages (from zict>=0.1.3->distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gowth\anaconda3\lib\site-packages (from jinja2->distributed>=2.11.0->tsfresh>=0.17.0->sktime[all_extras]) (2.0.1)
# Requirement already satisfied: decorator in c:\users\gowth\anaconda3\lib\site-packages (from mne->sktime[all_extras]) (5.1.1)
# Collecting pooch>=1.5
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\gowth\anaconda3\lib\site-packages (from pooch>=1.5->mne->sktime[all_extras]) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gowth\anaconda3\lib\site-packages (from plotly->statsforecast>=0.5.2->sktime[all_extras]) (8.0.1)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\gowth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (1.42.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\gowth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (3.19.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\gowth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (1.33.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\gowth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\gowth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (2.0.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\gowth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\gowth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (4.7.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\gowth\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->sktime[all_extras]) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp39-cp39-win_amd64.whl (101 kB)
# Building wheels for collected packages: filterpy, pykalman, pymeeus, pyod, keras-self-attention
#   Building wheel for filterpy (setup.py): started
#   Building wheel for filterpy (setup.py): finished with status 'done'
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=0e429bad3e480ec72f8e9e5896aa4b19c6e88a48fe89f6f012cec48e74525fb3
#   Stored in directory: c:\users\gowth\appdata\local\pip\cache\wheels\53\e6\de\a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
#   Building wheel for pykalman (setup.py): started
#   Building wheel for pykalman (setup.py): finished with status 'done'
#   Created wheel for pykalman: filename=pykalman-0.9.5-py3-none-any.whl size=48462 sha256=be964e23454c3b3637f3627a1e74bcea68bdd178878899d5cda9148ba923c322
#   Stored in directory: c:\users\gowth\appdata\local\pip\cache\wheels\7a\68\21\675239322d2bb2e8e1fa317d4bd7b5566a4e82780b25a27f7a
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732018 sha256=cfb550ffe5c0643d1758f6fdbbbf0a33d1b2540f80ddb82e34bd73180e33c3f9
#   Stored in directory: c:\users\gowth\appdata\local\pip\cache\wheels\04\1f\e5\8dd0c661cd8d252817655dc14a84f7ae045d6616594145aa81
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.7-py3-none-any.whl size=181103 sha256=b94dc32bb90b021b32e064c8b6a4f7beba809387924c55c4cdb07e8af97ede93
#   Stored in directory: c:\users\gowth\appdata\local\pip\cache\wheels\f4\1b\1a\a1d14cff28ea755d9c482bf64e2f349e1768504563856d7413
#   Building wheel for keras-self-attention (setup.py): started
#   Building wheel for keras-self-attention (setup.py): finished with status 'done'
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=b2bebecb666e8862f2467839dcd0fce3b626fa9f7abbc5eba4932acd6c735c53
#   Stored in directory: c:\users\gowth\appdata\local\pip\cache\wheels\78\c1\84\b83a2fd6f1d63e136cba74bac4126bee3b8705eef6486635fd
# Successfully built filterpy pykalman pymeeus pyod keras-self-attention
# Installing collected packages: oauthlib, requests-oauthlib, numpy, tensorboard-plugin-wit, tensorboard-data-server, pymeeus, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, korean-lunar-calendar, keras, hijri-converter, google-pasta, gast, flatbuffers, ephem, convertdate, astunparse, tensorflow-intel, stumpy, setuptools-git, pooch, LunarCalendar, holidays, dm-tree, cmdstanpy, tslearn, tsfresh, tensorflow-probability, tensorflow, tbats, statsforecast, scikit-posthocs, pyod, pykalman, prophet, mne, keras-self-attention, hmmlearn, gluonts, filterpy, esig, dtw-python
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\gowth\\anaconda3\\Lib\\site-packages\\~umpy\\core\\_multiarray_tests.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install tbats
# Out:
# Collecting tbats
#   Using cached tbats-1.1.2-py3-none-any.whl (43 kB)
# Requirement already satisfied: scikit-learn in c:\users\gowth\anaconda3\lib\site-packages (from tbats) (1.0.2)
# Requirement already satisfied: numpy in c:\users\gowth\anaconda3\lib\site-packages (from tbats) (1.21.6)
# Requirement already satisfied: pmdarima in c:\users\gowth\anaconda3\lib\site-packages (from tbats) (2.0.2)
# Requirement already satisfied: scipy in c:\users\gowth\anaconda3\lib\site-packages (from tbats) (1.7.3)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (0.13.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (61.2.0)
# Requirement already satisfied: pandas>=0.19 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (1.4.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (1.1.0)
# Requirement already satisfied: urllib3 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (1.26.9)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\gowth\anaconda3\lib\site-packages (from pmdarima->tbats) (0.29.28)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gowth\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima->tbats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gowth\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima->tbats) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\gowth\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima->tbats) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gowth\anaconda3\lib\site-packages (from scikit-learn->tbats) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\gowth\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima->tbats) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\gowth\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima->tbats) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\gowth\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima->tbats) (3.0.4)
# Installing collected packages: tbats
# Successfully installed tbats-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from sktime.forecasting.bats import BATS

forecaster = BATS(use_box_cox=True,
                  use_trend=False,
                  use_damped_trend=False,
                  sp=[24, 168])
forecaster.fit(y_train)

y_pred_BATS = forecaster.predict(fh)

# %% [markdown]
# ### TBATS

# %%
#Forecasting using TBATS turns out to be exactly like using BATS,only now we use TBATS!
from sktime.forecasting.tbats import TBATS

forecaster = TBATS(use_box_cox=True,
                   use_trend=False,
                   use_damped_trend=False,
                   sp=[24, 168])
forecaster.fit(y_train)

y_pred_TBATS = forecaster.predict(fh)

# %%
# Evaluating the performance
# At this point, we have predictions from our baseline model, BATS, and TBATS. We are then ready to visualize the predictions and see which model performs best.
# Visualizing the predictions gives the following plot.

# %%
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(y_train, ls='-', label='Train')
ax.plot(y_test, ls='-', label='Test')
ax.plot(y_test.index, y_pred_baseline, ls=':', label='Baseline')
ax.plot(y_pred_BATS, ls='--', label='BATS')
ax.plot(y_pred_TBATS, ls='-.', label='TBATS')
ax.set_xlabel('time')
ax.set_ylabel('Daily traffic volume')
ax.legend(loc='best')

fig.autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Forecasting the next 168 hours of traffic volume. We can see that all models seem to generate similar predictions, as the lines overlap one another. It is hard to know which model performs best by looking at the plot.

# %%
# Looking at the figure above, it seems that all of our models generate very similar predictions, as the lines are overlapping. It is very hard to determine which model performs best just by looking at the plot.
# We can optionally zoom in on the test set to better visualize the predictions.

# %%
# Zooming in on the test set. Here, it seems that BATS does a great job at modeling both seasonalities, whereas TBATS sometimes overshoots or undershoots. 
# Note that the baseline also follows the actual values very well.
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(y_train, ls='-', label='Train')
ax.plot(y_test, ls='-', label='Test')
ax.plot(y_test.index, y_pred_baseline, ls=':', label='Baseline')
ax.plot(y_pred_BATS, ls='--', label='BATS')
ax.plot(y_pred_TBATS, ls='-.', label='TBATS')
ax.set_xlabel('time')
ax.set_ylabel('Daily traffic volume')
ax.legend(loc='best')

fig.autofmt_xdate()
plt.tight_layout()

plt.xlim(800, 1000)
plt.ylim(0, 8000)

plt.show()

# %% [markdown]
# #### 1.Looking at the figure above, we first notice that both models indeed model a double seasonality, which is great in itself! Also, it seems that BATS does a better job at predicting the future, since TBATS seems to sometimes overshoot or undershoot. Note also that the baseline model closely follows the curve of actual values.
# #### 2.We now compute an error metric to determine the best model and compare their performance. In this case, we use the mean absolute percentage error (MAPE), for its ease of interpretation. Recall that the closer the MAPE is to 0, the better the performance.
# #### 3.MAPE is not yet implemented in scikit-learn, so we define the function ourselves.

# %%
def mape(y_true, y_pred):
    return round(np.mean(np.abs((y_true - y_pred) / y_true)) * 100,2)

# %%
#Then, we simply compute the performance of each model and visualize it in bar chart.

# %%
mape_baseline = mape(y_test, y_pred_baseline)
mape_BATS = mape(y_test, y_pred_BATS)
mape_TBATS = mape(y_test, y_pred_TBATS)

print(f'MAPE from baseline: {mape_baseline}')
print(f'MAPE from BATS: {mape_BATS}')
print(f'MAPE from TBATS: {mape_TBATS}')
# Out:
# MAPE from baseline: 11.97
# MAPE from BATS: 19.58
# MAPE from TBATS: 29.53

# %%
#MAPE of all models. Here, the baseline model achieves the best performance as it has the lowest MAPE. 
fig, ax = plt.subplots()

x = ['Baseline', 'BATS', 'TBATS']
y = [mape_baseline, mape_BATS, mape_TBATS]

ax.bar(x, y, width=0.4)
ax.set_xlabel('Models')
ax.set_ylabel('MAPE (%)')
ax.set_ylim(0, 35)

for index, value in enumerate(y):
    plt.text(x=index, y=value + 1, s=str(round(value,2)), ha='center')

plt.tight_layout()

# %% [markdown]
# ### From the figure above, we can see that BATS performed better than TBATS, which is to be expected as we observed from the plot. However, we see that the baseline model is the best performing model, achieving a MAPE of 11.97%.
